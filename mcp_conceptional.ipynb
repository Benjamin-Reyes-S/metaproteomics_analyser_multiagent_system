# %% [markdown]
# # mcp_data:
# functions to extract properties of the data and metadata which information is there and which analysis is possible with that information.  For example:

# %%
def available_batch_labels():
	return batch_labels


def number_of_studies():
	studies: [str]
	return studies, len[studies]


def number_of_samples():
		sample_labels: [str]
	return sample_labels, len[sample_labels]

# %% [markdown]
# # mcp_analyzer:
# functions for tests and plots for example:

# %%
def PERMANOVA():
	return PERMANOVA_values

def MMUPHin_batch_correction():
	return batch_correction_values

def pcoa_calculation():
	return pcoa_data

# %% [markdown]
# Each tool should return structured metadata, not only an image object like:

# %%
{
  "plot_path": "plots/pcoa_batch_corrected.png",
  "plot_type": "PCoA",
  "description": "PCoA colored by diagnosis and shaped by study_id",
  "parameters": {
    "color_by": "diagnosis",
    "shape_by": "study_id"
  },
  "warnings": []
}

# %% [markdown]
# # mcp_visualizer
#  functions to plot data and processed data

# %%
def pcoa(pcoa_data):
	return pcoa
    
def heatmap(some_data):
	return heatmap

# %%
from langchain.messages import AIMessage

def node(state: State):
    messages = state["messages"]
    new_message = AIMessage("Hello!")
    return {"messages": messages + [new_message], "extra_field": 10}

# %%
builder.add_node("study design", study_planner_node)
builder.add_node("analyze and plot", statistical_analyser)
builder.add_node("studdy validator", study_validator)
builder.add_node("evaluate output", outcome_auditor)

builder.add_edge(START, "Study design")
builder.add_edge("study design", "evaluate output")
builder.add_edge("evaluate output", "analyze and plot")
builder.add_edge("analyze and plot", "studdy validator")
builder.add_edge("studdy validator", END)

graph = builder.compile()


from IPython.display import Image, display

display(Image(graph.get_graph().draw_mermaid_png()))
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python (.venv - Metaproteomics) (Python 3.12.7)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#conceptual idea of the message structure and the structured_response
class AgentState(TypedDict):
    messages: list[AnyMessage]
    structured_response: NotRequired[ResponseT]
